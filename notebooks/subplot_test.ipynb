# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,100,100)
y = np.linspace(0,200,100)

plt.subplot(321)
plt.plot(x,y)

plt.subplot(322)
plt.plot(x,y)

plt.subplot(323)
plt.plot(x,y)

plt.subplot(324)
plt.plot(x,y)
