# %%
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import numpy as np
import datetime as dt
import pprint as pp
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
X = np.load("./X.npy")
y = np.load("./y.npy")
y = y[:-1]
X = X[:-1]

print(np.shape(X))


X_avg = np.zeros((681,22))

for i in range(22):
    X_avg[:,i] = np.mean(X[:,5*i:5+5*i],axis =1)
print(X_avg)
# Out:
# (681, 110)
# [[ 2.8   0.2   1.4  ...  0.4  -1.   12.96]
#  [ 3.8   0.2   1.6  ...  0.4  -1.   16.14]
#  [ 2.4   0.4   2.2  ...  0.6  -1.   16.92]
#  ...
#  [ 9.2   0.8   6.8  ...  4.6  15.6  48.  ]
#  [10.    0.6   7.   ...  4.6  18.   51.88]
#  [ 9.8   0.4   6.8  ...  4.4  20.4  50.58]]

# %%
plt.plot(list(range(0,len(y))),y)
list(range(0,len(y))),np.random.rand()*)
plt.show()
print(len(y))
# Out:
# 681

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=109, random_state=0,n_estimators=10000,criterion = 'mse',n_jobs =8)
train_split = 2/3
train_n = int(len(y)*train_split)
X = X_avg
regr.fit(X[:train_n],y[:train_n])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=109,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10000, n_jobs=8,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
plt.plot(list(range(train_n,len(y))),regr.predict(X[train_n:]),'r')
plt.plot(list(range(train_n,len(y))),y[train_n:],'b')
plt.show()
print(regr.score(X[train_n:],y[train_n:]))
# Out:
# -0.35222395530224615

# %%
# Out:
# array([23.3, 20.3, 29. , 15.9, 11.6,  5.4, 34.1, 41.3, 34.6, 13.9, 21.4,
#        13.6, 13.5, 15.5, 50.3, 26. ,  6.4, 16.1, 20.7, 33.1, 21.6, 18.4,
#        24.3, 22.3, 21.7, 13.9,  8.4,  5.1, 21.2,  9. , 24.9, 18.2, 23.9,
#        17.1, 16.6, 14.8, 23.1, 33.9, 18.3, 10.9, 15.7, 15.7, 15.2,  9.4,
#         7.4, 25.6, 30. , 25. , 15.3, 13.6, 21.4,  9.4, 20.3,  6.2, 32.5,
#        35.6, 22.4, 16.4, 36.4, 19.3,  4.4, 27.3, 17.1, 17.9, 14.8, 20.8,
#         5.2,  5.4, 26.1, 18.8, 16.3, 17.3,  7.2,  8.9,  6.1, 11.7, 10.3,
#        12.2, 20.6, 29.5,  9.5, 20.6, 25.2, 40.8, 18.2, 14.1, 14.2, 18.4,
#        19. , 32.9, 29.3, 20.9, 14.7, 21.4, 15.2, 26.1, 27.8, 14.2, 31.4,
#        22.8, 31.5, 30.6, 32.3, 24.2, 24.4, 12.6, 33.9, 23.3, 17.5, 13.8,
#         9.7, 15.6, 12.7, 13.9,  9.9, 31.3, 18.4, 20.7, 11.2, 26.7, 28.7,
#        15.8, 27.4, 10. , 32.8, 25.9, 23.2, 21.6, 29.1, 29.2, 25.7, 45.2,
#        66.7, 53.8, 64.2, 54.1, 43. , 32.7, 52.9, 43.6, 44.1, 69.8, 74.9,
#        28. , 41.9, 37.5, 71.2, 37.8, 38. , 60.1, 48.3, 66.4, 45.3, 34.4,
#        36.3, 49.9, 37.6, 67. , 26.9, 67.3, 51.2, 61.8, 42.6, 44.5, 71.6,
#        35.8, 63.2, 34.8, 38.4, 43.7, 52.2, 44.2, 47.2, 33.9, 40.7, 60.5,
#        35.4, 68.7, 49.8, 41.8, 56.1, 51.4, 17.7, 84.1, 42.7, 59.4, 61.5,
#        63.8, 51.9, 51.3, 51. , 53.1, 44.9, 29.1, 68.3, 45.1, 43.6, 46.4,
#        44.2, 38.5, 51.5, 45.1, 37.3, 40.7, 46. , 49.5, 21.9, 41.5, 52.1,
#        43.3, 35.5, 44.1, 28.5, 40.1, 32.6, 71.4, 52. , 60. , 64.2, 24.6,
#        57.9, 74.9, 57.8, 38.8, 49.1, 61.5, 59.3, 59.5, 55. , 68. , 32.8,
#        51.7, 70.9, 45. , 69. , 53.8, 41.6, 35.6, 42.4, 49. , 56. , 47.2,
#        63.4, 68.4, 62.5, 53.6, 45.2, 42.8, 66.3, 41. , 45.9, 72.3, 41.2,
#        47.8, 63.9, 45.4, 43.4, 73.9, 62.7, 58.3, 53.5, 55.9, 50.7, 55.9,
#        43.9, 66.4, 56.8, 51.1, 55.7, 43.8, 59.4, 46.5, 68.5, 42.9, 56.1,
#        50.7, 47.8, 56.3, 64.1, 47.2, 57.7, 60.3, 53.5, 55. , 43.9, 49. ,
#        52.5, 75.6, 89.7, 53. , 53.6, 33.2, 70.5, 69. , 61.2, 40.1, 48.9,
#        69.4, 61.2, 36.7, 60.2, 54.6, 54.2, 90.1, 34. , 28.4, 70.6, 73.9,
#        56.7, 52.2, 51.2, 69.4, 43.8, 47. , 55.4, 39.1, 58.9, 53.6, 51.8,
#        49.9, 68.5, 48.9, 75.3, 65. , 69.9, 77.9, 41. , 53.7, 42.6, 40.4,
#        62.4, 63.8, 63.7, 29.4, 68. , 50.7, 48.1, 44.1, 36. , 54.1, 53.5,
#        39.8, 52.3, 43.5, 50.1, 76.9, 80.7, 54.8, 57.5, 55.7, 64.9, 51.5,
#        37.1, 62.4, 69. , 55.6, 56.3, 40.7, 69.1, 67.7, 40.8, 49.4, 45.7,
#        46.2, 68.1, 68.8, 67.6, 54.2, 28.2, 69.9, 32.9, 42.4, 43.9, 55.5,
#        50.5, 54. , 98.5, 52.9, 38.7, 49.3, 62.8, 47.9, 47.7, 62.7, 55.3,
#        48.9, 59.1, 52.7, 44.1, 63.4, 50.5, 51. , 47.4, 41.2, 43.5, 61.2,
#        61.8, 55.7, 47.1, 43.2, 56.5, 57.6, 35.6, 66.5, 36.7, 45.3])
