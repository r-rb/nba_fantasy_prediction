# %%
from nba_py import player
from nba_py.player import get_player
from nba_py import constants
from nba_py import team
from nba_py import game
from nba_py.constants import TEAMS

import pickle
import re
import time
import json
import pprint as pp
import sys
import pandas as pd

from time import time,sleep

# %%
def scrape_matchups(): 
    
    df = pd.read_pickle('../data/player_game_table.pkl')
    seasons = ["2017-2018", "2016-2017", "2015-2016"]
    #print(df.head(1))
    game_ids = df.loc[(df.player_id == "2544") & (df.season.isin(seasons))]
    player_ids = set([])
    count = 0
    for idx, row in game_ids.iterrows():
        if not count%10:
            print(count, " out of ", game_ids.shape)
        count += 1
        
        all_games = df.loc[(df.game_id == row.game_id) & (df.team_id != row.team_id)]
        #print(all_games)
        for idx, game_row in all_games.iterrows():
            player_ids.add(game_row.player_id)

    print(len(player_ids))
    print(player_ids)
    
    return player_ids

# %%
player_ids = scrape_matchups()
# Out:
# 0  out of  (232, 33)
# 10  out of  (232, 33)
# 20  out of  (232, 33)
# 30  out of  (232, 33)
# 40  out of  (232, 33)
# 50  out of  (232, 33)
# 60  out of  (232, 33)
# 70  out of  (232, 33)
# 80  out of  (232, 33)
# 90  out of  (232, 33)
# 100  out of  (232, 33)
# 110  out of  (232, 33)
# 120  out of  (232, 33)
# 130  out of  (232, 33)
# 140  out of  (232, 33)
# 150  out of  (232, 33)
# 160  out of  (232, 33)
# 170  out of  (232, 33)
# 180  out of  (232, 33)
# 190  out of  (232, 33)
# 200  out of  (232, 33)
# 210  out of  (232, 33)
# 220  out of  (232, 33)
# 230  out of  (232, 33)
# 559
# {'1627773', '201145', '203924', '202334', '1627758', '200768', '201599', '203906', '1628407', '203948', '203530', '203485', '1628414', '201588', '201196', '1627775', '1938', '201574', '1628425', '1627884', '1627816', '203992', '204025', '202711', '201583', '202734', '203112', '203200', '202704', '2863', '2216', '2756', '202389', '1626199', '2581', '1713', '1626168', '1626167', '1628393', '201935', '203087', '203918', '203894', '2772', '101179', '1626150', '1626156', '101123', '204067', '204001', '202703', '203114', '203187', '1627749', '1628462', '1718', '202718', '202326', '1626204', '201933', '201177', '2406', '1626196', '1627752', '201977', '1627774', '1628374', '200782', '203613', '2738', '1495', '203943', '203496', '203484', '201603', '101114', '1626145', '203092', '1628367', '203094', '1628439', '202692', '201973', '1627826', '2207', '202730', '203546', '203994', '201939', '1627737', '1628416', '201563', '1627761', '1626155', '202322', '1626273', '1628368', '2730', '202324', '1626149', '1891', '101127', '203921', '203124', '1628391', '1627734', '201960', '2754', '200826', '203084', '203930', '203471', '977', '2440', '203500', '101181', '1627739', '1626259', '204037', '203901', '2749', '203967', '203120', '2733', '101135', '1628388', '200745', '203903', '203893', '1627815', '1626178', '203186', '101187', '201951', '202722', '201579', '203956', '202683', '203083', '1627827', '203919', '201967', '202696', '202694', '1626171', '1627755', '201577', '1628467', '203110', '2399', '202708', '1626257', '202713', '1626175', '203090', '203076', '1628404', '1626179', '201580', '1626158', '1626181', '201166', '202338', '201980', '200794', '1628365', '203078', '201962', '203926', '1627757', '201571', '203939', '1627098', '1627362', '2594', '202362', '203462', '1627732', '203138', '1627777', '201589', '203101', '1627738', '101112', '1627885', '201171', '204020', '1628464', '203512', '1627835', '203473', '202357', '200797', '201600', '1626253', '203961', '203917', '201950', '1626166', '1628370', '203922', '1627819', '1627788', '201144', '101162', '2419', '2734', '203488', '1628380', '1627751', '1627747', '203461', '1626144', '203088', '2400', '202388', '201609', '203468', '1627849', '101141', '204456', '1626245', '2200', '2736', '1627750', '101139', '1626170', '202083', '202682', '203141', '200811', '203934', '202391', '203077', '201943', '203585', '203940', '201586', '101161', '1627781', '2588', '2405', '1627823', '201988', '1626176', '203093', '1628386', '203148', '202325', '203493', '201601', '203156', '1628390', '201937', '1628373', '202738', '202331', '1627812', '203457', '201946', '203081', '200779', '203524', '2547', '203504', '1627733', '2034', '1628463', '202327', '201976', '1627863', '203920', '1628384', '202341', '203464', '1626153', '202702', '203503', '203900', '201155', '101108', '204060', '203552', '1627851', '201143', '2617', '1628422', '202498', '202339', '1717', '1626202', '203946', '2449', '201148', '2585', '1627770', '201566', '201584', '1628400', '203487', '201228', '201168', '2731', '203210', '1627832', '203584', '1628372', '203518', '203079', '201949', '708', '203923', '201587', '201147', '203515', '203107', '203490', '200755', '1627783', '1627785', '2744', '1627824', '1628021', '1628382', '1627848', '203115', '203996', '1626161', '1627846', '203486', '1626173', '1627855', '1626159', '2561', '203962', '202347', '203382', '2550', '203508', '1627763', '203089', '1628469', '1627736', '203960', '1626164', '1628366', '203096', '202349', '203937', '201149', '201573', '203080', '1627759', '202700', '1627756', '1628436', '1628415', '203912', '202779', '1627742', '1626185', '2571', '203954', '2755', '203914', '2446', '203476', '203527', '203477', '1626214', '201572', '1626242', '203506', '2037', '200771', '200757', '202087', '203935', '202329', '203957', '203469', '1627875', '1627868', '203463', '202709', '201162', '201202', '1626151', '201152', '202390', '1628411', '203459', '101106', '202066', '1628398', '203095', '203909 ...

# %%
def not_really_scraping(player_ids):
    t0 = time()
    api_seasons = ["2017-18", "2016-17", "2015-16"]
    headers = ['player_id', 'min', 'fgm', 'fga', 'fg3m', 
    'fg3a', 'ftm', 'fta', 'oreb', 'dreb', 'reb', 'ast', 'tov','stl', 'blk', 'pts', 'season', 'player_vs_id', 'fp']
    not_input = {}
    for header in headers:
        not_input[header] = []
    count = 0
    responses = []
    
    for player_id in player_ids:
        count += 1
        
        for season in api_seasons:
            sleep(3)
            response = player.PlayerVsPlayer(2544,player_id, season=season).json
            print(response)
            responses.append(response)
            
            for header in headers:
                if header.upper() in response['resultSets'][0]['headers']:
                    idx = response['resultSets'][0]['headers'].index(header.upper())
                    not_input[header].append(str(response['resultSets'][0]['rowSet'][0][idx]))
                
            #add FP
            not_input['season'].append(season)
            not_input['player_vs_id'].append(player_id)
            not_input['fp'].append('meme')
            
        if not(count%10):
            print(count, " out of ", len(player_ids))
            print('Just completed: ' + str(count) + ' with an ETC of ' +  str( ((time() - t0)/(count)) * (len(player_ids) - (count) )))
            #assert(1==0)
    #pp.pprint(response['resultSets'][0])
    df = pd.DataFrame(data=not_input)
    df.to_pickle('./player_vs_table.pkl')
    pickle.dump(responses,open('./raw_player_matchup_responses.pkl','wb'))

# %%
def not_really_scraping_v2(player_ids):
    t0 = time()
    api_seasons = ["2017-18", "2016-17", "2015-16"]
    headers = ['player_id', 'min', 'fgm', 'fga', 'fg3m', 
    'fg3a', 'ftm', 'fta', 'oreb', 'dreb', 'reb', 'ast', 'tov','stl', 'blk', 'pts', 'season', 'player_vs_id']
    not_input = {}
    for header in headers:
        not_input[header] = []
    count = 0
    responses = pd.read_pickle('../data/raw_player_matchup_responses.pkl')
    responses.reverse()

    
    for player_id in player_ids:
        count += 1
        for season in api_seasons:
            response = responses.pop()
            played = False
            for header in headers:
                if header.upper() in response['resultSets'][1]['headers']:
                    idx = response['resultSets'][1]['headers'].index(header.upper())
                    if len(response['resultSets'][1]['rowSet']):
                        played = True
                        not_input[header].append(str(response['resultSets'][1]['rowSet'][0][idx]))
                    else:
                        break
            if played:
                not_input['season'].append(season)
                not_input['player_vs_id'].append(player_id)
            
        if not(count%10):
            print(count, " out of ", len(player_ids))
            print('Just completed: ' + str(count) + ' with an ETC of ' +  str( ((time() - t0)/(count)) * (len(player_ids) - (count) )))
    print(not_input)
    df = pd.DataFrame(data=not_input)
    df.to_pickle('./player_vs_table_2.pkl')

# %%
not_really_scraping_v2(player_ids)
# Out:
# 10  out of  559
# Just completed: 10 with an ETC of 32.45858781337738
# 20  out of  559
# Just completed: 20 with an ETC of 15.987150371074677
# 30  out of  559
# Just completed: 30 with an ETC of 10.521573742230732
# 40  out of  559
# Just completed: 40 with an ETC of 7.7677495121955875
# 50  out of  559
# Just completed: 50 with an ETC of 6.119714646339417
# 60  out of  559
# Just completed: 60 with an ETC of 5.0160776217778515
# 70  out of  559
# Just completed: 70 with an ETC of 4.230650997161865
# 80  out of  559
# Just completed: 80 with an ETC of 3.640965542197227
# 90  out of  559
# Just completed: 90 with an ETC of 3.1791884740193685
# 100  out of  559
# Just completed: 100 with an ETC of 2.8093666648864746
# 110  out of  559
# Just completed: 110 with an ETC of 2.5084545785730534
# 120  out of  559
# Just completed: 120 with an ETC of 2.255459825197856
# 130  out of  559
# Just completed: 130 with an ETC of 2.041084599494934
# 140  out of  559
# Just completed: 140 with an ETC of 1.8570517080170765
# 150  out of  559
# Just completed: 150 with an ETC of 1.6972926362355552
# 160  out of  559
# Just completed: 160 with an ETC of 1.5572554036974906
# 170  out of  559
# Just completed: 170 with an ETC of 1.4334580491570865
# 180  out of  559
# Just completed: 180 with an ETC of 1.32319555150138
# 190  out of  559
# Just completed: 190 with an ETC of 1.2243322171662983
# 200  out of  559
# Just completed: 200 with an ETC of 1.13515549659729
# 210  out of  559
# Just completed: 210 with an ETC of 1.0542848598389398
# 220  out of  559
# Just completed: 220 with an ETC of 0.9813479759476402
# 230  out of  559
# Just completed: 230 with an ETC of 0.9131201039189878
# 240  out of  559
# Just completed: 240 with an ETC of 0.8511114140351613
# 250  out of  559
# Just completed: 250 with an ETC of 0.7945194797515869
# 260  out of  559
# Just completed: 260 with an ETC of 0.7420894145965576
# 270  out of  559
# Just completed: 270 with an ETC of 0.6938896497090657
# 280  out of  559
# Just completed: 280 with an ETC of 0.6479326256683895
# 290  out of  559
# Just completed: 290 with an ETC of 0.6050081992971486
# 300  out of  559
# Just completed: 300 with an ETC of 0.5643837396303812
# 310  out of  559
# Just completed: 310 with an ETC of 0.526683562032638
# 320  out of  559
# Just completed: 320 with an ETC of 0.491956938803196
# 330  out of  559
# Just completed: 330 with an ETC of 0.4588095968419855
# 340  out of  559
# Just completed: 340 with an ETC of 0.4277864350992091
# 350  out of  559
# Just completed: 350 with an ETC of 0.3977726752417428
# 360  out of  559
# Just completed: 360 with an ETC of 0.36959108975198535
# 370  out of  559
# Just completed: 370 with an ETC of 0.34229175335652123
# 380  out of  559
# Just completed: 380 with an ETC of 0.31681822224667194
# 390  out of  559
# Just completed: 390 with an ETC of 0.29230895042419436
# 400  out of  559
# Just completed: 400 with an ETC of 0.26912306070327763
# 410  out of  559
# Just completed: 410 with an ETC of 0.24658659725654414
# 420  out of  559
# Just completed: 420 with an ETC of 0.22521657716660273
# 430  out of  559
# Just completed: 430 with an ETC of 0.20474867820739745
# 440  out of  559
# Just completed: 440 with an ETC of 0.18512045632709156
# 450  out of  559
# Just completed: 450 with an ETC of 0.16627644856770832
# 460  out of  559
# Just completed: 460 with an ETC of 0.14827254699624104
# 470  out of  559
# Just completed: 470 with an ETC of 0.13083511819230748
# 480  out of  559
# Just completed: 480 with an ETC of 0.11395996858676274
# 490  out of  559
# Just completed: 490 with an ETC of 0.09785256531773781
# 500  out of  559
# Just completed: 500 with an ETC of 0.08229028511047363
# 510  out of  559
# Just completed: 510 with an ETC of 0.06724100206412521
# 520  out of  559
# Just completed: 520 with an ETC of 0.05263792276382446
# 530  out of  559
# Just completed: 530 with an ETC of 0.038511087759485786
# 540  out of  559
# Just completed: 540 with an ETC of 0.024833948965425845
# 550  out of  559
# Just completed: 550 with an ETC of 0.011590150919827548
